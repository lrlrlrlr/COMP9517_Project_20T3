# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
import csv
from sklearn.metrics import confusion_matrix
import glob, os

def tt(im, fg, canon):
    image = cv2.imread(im)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    he = image.shape[0]
    we = image.shape[1]
    print(im)
    
    #the segmentation algorithm
    #ignore top of image
    for y in range(0, int(0.07*he)):
        for x in range(0, we):
            if(canon == 1 and y < 0.065*he):
                image[y, x] = (255,255,255)
                
                
    #LAB
    LAB = cv2.cvtColor(image, cv2.COLOR_BGR2LAB)
    lower_green = np.array([1,1,80])
    upper_green = np.array([255,100,217])
    mask = cv2.inRange(LAB, lower_green, upper_green)
    mask = cv2.medianBlur(mask,3)
    print("Projected")
    plt.imshow(mask, cmap=plt.cm.gray)
    plt.show()
    
    #ground truth
    image_c = cv2.imread(fg)
    image_c = cv2.cvtColor(image_c, cv2.COLOR_BGR2GRAY)
    print("Ground truth")
    plt.imshow(image_c, cmap=plt.cm.gray)
    plt.show()
    
    #dice similarity coefficient
    image_c = cv2.normalize(image_c, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=1)
    image_c = np.reshape(image_c,-1)

    mask = cv2.normalize(mask, None, alpha=0, beta=1, norm_type=cv2.NORM_MINMAX, dtype=1)
    mask = np.reshape(mask,-1)
    tn, fp, fn, tp = confusion_matrix(image_c, mask).ravel()
    dice = 2*tp/(2*tp + fp + fn)
    print("Dice: " + str(dice))
    
    #true positive / (true positive + false positive + false negative)
    iou = tp/(tp+fp+fn)
    print("IoU: " + str(iou))
    return dice, iou

f1 = []
b1 = []
d = []
io = []

cwd = os.getcwd() 

os.chdir("Tray/Ara2012/")
for file in glob.glob("*_rgb.png"):
    f1.append(file)
for file2 in glob.glob("*_fg.png"):
    b1.append(file2)
    
for x in range(len(f1)):
    d1, io1 = tt(f1[x],b1[x],0)
    d.append(d1)
    io.append(io1)
f1 = []
b1 = []    
os.chdir(cwd)

os.chdir("Tray/Ara2013-Canon/")
for file in glob.glob("*_rgb.png"):
    f1.append(file)
for file2 in glob.glob("*_fg.png"):
    b1.append(file2)
    
for x in range(len(f1)):
    d1, io1 = tt(f1[x],b1[x],1)
    d.append(d1)
    io.append(io1)
os.chdir(cwd)

print("Average dice value: " + str(np.mean(d)))
print("Average iou value: " + str(np.mean(io)))
# Out:
# ara2012_tray01_rgb.png
# Projected
# Ground truth
# Dice: 0.979728196770713
# IoU: 0.9602619553630234
# ara2012_tray02_rgb.png
# Projected
# Ground truth
# Dice: 0.9693292630972773
# IoU: 0.9404839279809348
# ara2012_tray03_rgb.png
# Projected
# Ground truth
# Dice: 0.9684364138737892
# IoU: 0.9388043809403156
# ara2012_tray04_rgb.png
# Projected
# Ground truth
# Dice: 0.9667974526042937
# IoU: 0.9357288704341724
# ara2012_tray05_rgb.png
# Projected
# Ground truth
# Dice: 0.9681385355104969
# IoU: 0.9382446857722978
# ara2012_tray06_rgb.png
# Projected
# Ground truth
# Dice: 0.966444019241597
# IoU: 0.9350669312874949
# ara2012_tray07_rgb.png
# Projected
# Ground truth
# Dice: 0.9641821696683939
# IoU: 0.9308414485969227
# ara2012_tray08_rgb.png
# Projected
# Ground truth
# Dice: 0.9602933100939708
# IoU: 0.9236194394216739
# ara2012_tray09_rgb.png
# Projected
# Ground truth
# Dice: 0.9512596142160182
# IoU: 0.9070496636828835
# ara2012_tray10_rgb.png
# Projected
# Ground truth
# Dice: 0.9463832886468796
# IoU: 0.898223498592268
# ara2012_tray11_rgb.png
# Projected
# Ground truth
# Dice: 0.939432615373782
# IoU: 0.8857830525354802
# ara2012_tray12_rgb.png
# Projected
# Ground truth
# Dice: 0.9318031379391523
# IoU: 0.8723140565508176
# ara2012_tray13_rgb.png
# Projected
# Ground truth
# Dice: 0.9230505143633541
# IoU: 0.8570973167025439
# ara2012_tray14_rgb.png
# Projected
# Ground truth
# Dice: 0.9138777010287671
# IoU: 0.8414132569549353
# ara2012_tray15_rgb.png
# Projected
# Ground truth
# Dice: 0.9089532418645734
# IoU: 0.833102005103753
# ara2012_tray16_rgb.png
# Projected
# Ground truth
# Dice: 0.8986774519799439
# IoU: 0.8159984135397709
# ara2013_tray01_rgb.png
# Projected
# Ground truth
# Dice: 0.9287344256309616
# IoU: 0.8669506869741187
# ara2013_tray02_rgb.png
# Projected
# Ground truth
# Dice: 0.9661599497211093
# IoU: 0.9345352305324949
# ara2013_tray03_rgb.png
# Projected
# Ground truth
# Dice: 0.9644737589342939
# IoU: 0.9313851457223441
# ara2013_tray04_rgb.png
# Projected
# Ground truth
# Dice: 0.9449537506074609
# IoU: 0.8956514950425483
# ara2013_tray05_rgb.png
# Projected
# Ground truth
# Dice: 0.9552078061946099
# IoU: 0.9142562624970504
# ara2013_tray06_rgb.png
# Projected
# Ground truth
# Dice: 0.9372530037803825
# IoU: 0.8819154578788369
# ara2013_tray07_rgb.png
# Projected
# Ground truth
# Dice: 0.9667967419546326
# IoU: 0.9357275390165107
# ara2013_tray08_rgb.png
# Projected
# Ground truth
# Dice: 0.9743010544237756
# IoU: 0.9498898859415573
# ara2013_tray09_rgb.png
# Projected
# Ground truth
# Dice: 0.975017883458485
# IoU: 0.9512535562555775
# ara2013_tray10_rgb.png
# Projected
# Ground truth
# Dice: 0.9683697450944945
# IoU: 0.9386790863197342
# ara2013_tray11_rgb.png
# Projected
# Ground truth
# Dice: 0.9821312776634245
# IoU: 0.9648899274642079
# ara2013_tray12_rgb.png
# Projected
# Ground truth
# Dice: 0.9758239263167766
# IoU: 0.9527892238367189
# ara2013_tray13_rgb.png
# Projected
# Ground truth
# Dice: 0.9705820415455789
# IoU: 0.942845453175133
# ara2013_tray14_rgb.png
# Projected
# Ground truth
# Dice: 0.9693991921275236
# IoU: 0.9406155950223885
# ara2013_tray15_rgb.png
# Projected
# Ground truth
# Dice: 0.9695629072665898
# IoU: 0.9409239186980923
# ara2013_tray16_rgb.png
# Projected
# Ground truth
# Dice: 0.983445180842031
# IoU: 0.9674295594374702
# ara2013_tray17_rgb.png
# Projected
# Ground truth
# Dice: 0.9680921527047022
# IoU: 0.9381575644008707
# ara2013_tray18_rgb.png
# Projected
# Ground truth
# Dice: 0.9778111697898852
# IoU: 0.9565856531506928
# ara2013_tray19_rgb.png
# Projected
# Ground truth
# Dice: 0.979754160514028
# IoU: 0.9603118411221899
# ara2013_tray20_rgb.png
# Projected
# Ground truth
# Dice: 0.968110336536891
# IoU: 0.9381917183740661
# ara2013_tray21_rgb.png
# Projected
# Ground truth
# Dice: 0.9783688932726876
# IoU: 0.9576537821041778
# ara2013_tray22_rgb.png
# Projected
# Ground truth
# Dice: 0.9768002566332882
# IoU: 0.9546525621861944
# ara2013_tray23_rgb.png
# Projected
# Ground truth
# Dice: 0.976761149837586
# IoU: 0.9545778580265489
# ara2013_tray24_rgb.png
# Projected
# Ground truth
# Dice: 0.9774746623916528
# IoU: 0.9559417517006803
# ara2013_tray25_rgb.png
# Projected
# Ground truth
# Dice: 0.9745189433225551
# IoU: 0.9503041884361989
# ara2013_tray26_rgb.png
# Projected
# Ground truth
# Dice: 0.9764491764596356
# IoU: 0.9539821120774358
# ara2013_tray27_rgb.png
# Projected
# Ground truth
# Dice: 0.9650446124731134
# IoU: 0.9324504457908751
# Average dice value: 0.9606554671109572
# Average iou value: 0.9250367535963723
